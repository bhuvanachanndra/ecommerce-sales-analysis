# %%
import pandas as pd
import numpy as np

np.random.seed(42)

n = 500

df = pd.DataFrame({
    "CustomerID": [f"CUST{i:04d}" for i in range(1, n + 1)],
    "Gender": np.random.choice(["Male", "Female"], n),
    "Age": np.random.randint(18, 70, n),
    "Tenure": np.random.randint(1, 73, n),
    "Contract": np.random.choice(
        ["Month-to-Month", "One Year", "Two Year"],
        n,
        p=[0.55, 0.25, 0.20]
    ),
    "MonthlyCharges": np.round(np.random.uniform(20, 120, n), 2),
    "PaymentMethod": np.random.choice(
        ["UPI", "Credit Card", "Bank Transfer", "Cash"],
        n
    ),
    "InternetService": np.random.choice(
        ["DSL", "Fiber", "No"],
        n
    ),
    "TechSupport": np.random.choice(["Yes", "No"], n),
    "OnlineSecurity": np.random.choice(["Yes", "No"], n),
    "Churn": np.random.choice(["Yes", "No"], n, p=[0.27, 0.73])
})

df["TotalCharges"] = np.round(
    df["Tenure"] * df["MonthlyCharges"], 2
)

df.head()
# Out:
#   CustomerID  Gender  Age  Tenure        Contract  MonthlyCharges  \
# 0   CUST0001    Male   38      63  Month-to-Month          104.72
# 1   CUST0002  Female   49      52        Two Year          111.42
# 2   CUST0003    Male   40      38        One Year          101.38
# 3   CUST0004    Male   50      30        One Year           30.89
# 4   CUST0005    Male   20      51        One Year           34.90
#
#    PaymentMethod InternetService TechSupport OnlineSecurity Churn  \
# 0  Bank Transfer             DSL         Yes            Yes    No
# 1  Bank Transfer             DSL         Yes            Yes   Yes
# 2  Bank Transfer             DSL         Yes            Yes    No
# 3           Cash              No          No            Yes   Yes
# 4    Credit Card             DSL         Yes             No    No
#
#    TotalCharges
# 0       6597.36
# 1       5793.84
# 2       3852.44
# 3        926.70
# 4       1779.90

# %%
df.to_csv("../data/customer_churn.csv", index=False)

print("Dataset created successfully!")
print("Rows:", len(df))
# Out:
# Dataset created successfully!
# Rows: 500

# %%
df.to_csv("customer_churn.csv", index=False)
print("Dataset saved in data folder successfully!")
# Out:
# Dataset saved in data folder successfully!

# %%
import pandas as pd

df = pd.read_csv("customer_churn.csv")

print("Dataset loaded successfully!")
print("Rows:", len(df))
print("Columns:", len(df.columns))

df.head()
# Out:
# Dataset loaded successfully!
# Rows: 500
# Columns: 12
#   CustomerID  Gender  Age  Tenure        Contract  MonthlyCharges  \
# 0   CUST0001    Male   38      63  Month-to-Month          104.72
# 1   CUST0002  Female   49      52        Two Year          111.42
# 2   CUST0003    Male   40      38        One Year          101.38
# 3   CUST0004    Male   50      30        One Year           30.89
# 4   CUST0005    Male   20      51        One Year           34.90
#
#    PaymentMethod InternetService TechSupport OnlineSecurity Churn  \
# 0  Bank Transfer             DSL         Yes            Yes    No
# 1  Bank Transfer             DSL         Yes            Yes   Yes
# 2  Bank Transfer             DSL         Yes            Yes    No
# 3           Cash              No          No            Yes   Yes
# 4    Credit Card             DSL         Yes             No    No
#
#    TotalCharges
# 0       6597.36
# 1       5793.84
# 2       3852.44
# 3        926.70
# 4       1779.90

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       500 non-null    str
#  1   Gender           500 non-null    str
#  2   Age              500 non-null    int64
#  3   Tenure           500 non-null    int64
#  4   Contract         500 non-null    str
#  5   MonthlyCharges   500 non-null    float64
#  6   PaymentMethod    500 non-null    str
#  7   InternetService  500 non-null    str
#  8   TechSupport      500 non-null    str
#  9   OnlineSecurity   500 non-null    str
#  10  Churn            500 non-null    str
#  11  TotalCharges     500 non-null    float64
# dtypes: float64(2), int64(2), str(8)
# memory usage: 47.0 KB

# %%
print("Missing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# CustomerID         0
# Gender             0
# Age                0
# Tenure             0
# Contract           0
# MonthlyCharges     0
# PaymentMethod      0
# InternetService    0
# TechSupport        0
# OnlineSecurity     0
# Churn              0
# TotalCharges       0
# dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
import pandas as pd

df = pd.read_csv("../data/customer_churn.csv")

print("Dataset loaded successfully!")
print("Rows:", len(df))
print("Columns:", len(df.columns))

df.head()
# Out:
# Dataset loaded successfully!
# Rows: 500
# Columns: 12
#   CustomerID  Gender  Age  Tenure        Contract  MonthlyCharges  \
# 0   CUST0001    Male   38      63  Month-to-Month          104.72
# 1   CUST0002  Female   49      52        Two Year          111.42
# 2   CUST0003    Male   40      38        One Year          101.38
# 3   CUST0004    Male   50      30        One Year           30.89
# 4   CUST0005    Male   20      51        One Year           34.90
#
#    PaymentMethod InternetService TechSupport OnlineSecurity Churn  \
# 0  Bank Transfer             DSL         Yes            Yes    No
# 1  Bank Transfer             DSL         Yes            Yes   Yes
# 2  Bank Transfer             DSL         Yes            Yes    No
# 3           Cash              No          No            Yes   Yes
# 4    Credit Card             DSL         Yes             No    No
#
#    TotalCharges
# 0       6597.36
# 1       5793.84
# 2       3852.44
# 3        926.70
# 4       1779.90

# %%
print("Dataset shape:", df.shape)
# Out:
# Dataset shape: (500, 12)

# %%
print("Column names:")
print(df.columns.tolist())
# Out:
# Column names:
# ['CustomerID', 'Gender', 'Age', 'Tenure', 'Contract', 'MonthlyCharges', 'PaymentMethod', 'InternetService', 'TechSupport', 'OnlineSecurity', 'Churn', 'TotalCharges']

# %%
df.describe()
# Out:
#               Age      Tenure  MonthlyCharges  TotalCharges
# count  500.000000  500.000000      500.000000    500.000000
# mean    43.800000   35.706000       68.747820   2445.230720
# std     14.835504   20.734691       28.480762   1852.435122
# min     18.000000    1.000000       20.030000     21.270000
# 25%     31.000000   18.000000       42.862500    975.587500
# 50%     44.000000   36.000000       69.195000   1964.710000
# 75%     56.000000   53.250000       93.790000   3655.662500
# max     69.000000   72.000000      119.550000   7954.130000

# %%
print(df["Churn"].value_counts())
# Out:
# Churn
# No     387
# Yes    113
# Name: count, dtype: int64

# %%
print(df["Churn"].value_counts(normalize=True) * 100)
# Out:
# Churn
# No     77.4
# Yes    22.6
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(data=df, x="Churn")
plt.title("Customer Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Number of Customers")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.countplot(data=df, x="Contract", hue="Churn")

plt.title("Customer Churn by Contract Type")
plt.xlabel("Contract Type")
plt.ylabel("Number of Customers")
plt.xticks(rotation=15)
plt.show()

# %%
churn_by_contract = pd.crosstab(
    df["Contract"],
    df["Churn"],
    normalize="index"
) * 100

print(churn_by_contract.round(2))
# Out:
# Churn              No    Yes
# Contract
# Month-to-Month  77.82  22.18
# One Year        74.81  25.19
# Two Year        79.80  20.20

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(data=df, x="Churn", y="MonthlyCharges")

plt.title("Monthly Charges vs Customer Churn")
plt.xlabel("Churn")
plt.ylabel("Monthly Charges")
plt.show()

# %%
df.groupby("Churn")["MonthlyCharges"].mean().round(2)
# Out:
# Churn
# No     69.34
# Yes    66.72
# Name: MonthlyCharges, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(data=df, x="Churn", y="Tenure")

plt.title("Customer Tenure vs Churn")
plt.xlabel("Churn")
plt.ylabel("Tenure (Months)")
plt.show()

# %%
df.groupby("Churn")["Tenure"].mean().round(2)
# Out:
# Churn
# No     36.41
# Yes    33.30
# Name: Tenure, dtype: float64

# %%
plt.figure(figsize=(10, 5))

sns.countplot(data=df, x="PaymentMethod", hue="Churn")

plt.title("Customer Churn by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Number of Customers")
plt.xticks(rotation=20)
plt.show()

# %%
payment_churn = pd.crosstab(
    df["PaymentMethod"],
    df["Churn"],
    normalize="index"
) * 100

print(payment_churn.round(2))
# Out:
# Churn             No    Yes
# PaymentMethod
# Bank Transfer  75.81  24.19
# Cash           75.91  24.09
# Credit Card    82.50  17.50
# UPI            75.63  24.37

# %%
plt.figure(figsize=(8, 5))

sns.countplot(data=df, x="InternetService", hue="Churn")

plt.title("Customer Churn by Internet Service")
plt.xlabel("Internet Service")
plt.ylabel("Number of Customers")
plt.show()

# %%
internet_churn = pd.crosstab(
    df["InternetService"],
    df["Churn"],
    normalize="index"
) * 100

print(internet_churn.round(2))
# Out:
# Churn               No    Yes
# InternetService
# DSL              78.89  21.11
# Fiber            76.19  23.81
# No               76.88  23.12

# %%
plt.figure(figsize=(8, 5))

sns.countplot(data=df, x="TechSupport", hue="Churn")

plt.title("Customer Churn by Tech Support")
plt.xlabel("Tech Support")
plt.ylabel("Number of Customers")
plt.show()

# %%
techsupport_churn = pd.crosstab(
    df["TechSupport"],
    df["Churn"],
    normalize="index"
) * 100

print(techsupport_churn.round(2))
# Out:
# Churn           No    Yes
# TechSupport
# No           80.15  19.85
# Yes          74.37  25.63

# %%
print("========== CUSTOMER CHURN SUMMARY ==========")

print("\n1. Overall Churn:")
print(df["Churn"].value_counts())

print("\n2. Churn Percentage:")
print((df["Churn"].value_counts(normalize=True) * 100).round(2))

print("\n3. Average Monthly Charges:")
print(df.groupby("Churn")["MonthlyCharges"].mean().round(2))

print("\n4. Average Tenure:")
print(df.groupby("Churn")["Tenure"].mean().round(2))

print("\n5. Churn by Contract:")
print(
    pd.crosstab(
        df["Contract"],
        df["Churn"],
        normalize="index"
    ).mul(100).round(2)
)

print("\n6. Churn by Payment Method:")
print(
    pd.crosstab(
        df["PaymentMethod"],
        df["Churn"],
        normalize="index"
    ).mul(100).round(2)
)

print("\n7. Churn by Internet Service:")
print(
    pd.crosstab(
        df["InternetService"],
        df["Churn"],
        normalize="index"
    ).mul(100).round(2)
)

print("\n8. Churn by Tech Support:")
print(
    pd.crosstab(
        df["TechSupport"],
        df["Churn"],
        normalize="index"
    ).mul(100).round(2)
)
# Out:
# ========== CUSTOMER CHURN SUMMARY ==========
#
# 1. Overall Churn:
# Churn
# No     387
# Yes    113
# Name: count, dtype: int64
#
# 2. Churn Percentage:
# Churn
# No     77.4
# Yes    22.6
# Name: proportion, dtype: float64
#
# 3. Average Monthly Charges:
# Churn
# No     69.34
# Yes    66.72
# Name: MonthlyCharges, dtype: float64
#
# 4. Average Tenure:
# Churn
# No     36.41
# Yes    33.30
# Name: Tenure, dtype: float64
#
# 5. Churn by Contract:
# Churn              No    Yes
# Contract
# Month-to-Month  77.82  22.18
# One Year        74.81  25.19
# Two Year        79.80  20.20
#
# 6. Churn by Payment Method:
# Churn             No    Yes
# PaymentMethod
# Bank Transfer  75.81  24.19
# Cash           75.91  24.09
# Credit Card    82.50  17.50
# UPI            75.63  24.37
#
# 7. Churn by Internet Service:
# Churn               No    Yes
# InternetService
# DSL              78.89  21.11
# Fiber            76.19  23.81
# No               76.88  23.12
#
# 8. Churn by Tech Support:
# Churn           No    Yes
# TechSupport
# No           80.15  19.85
# Yes          74.37  25.63
